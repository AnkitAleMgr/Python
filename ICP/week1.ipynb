# %%
numbers = [10, 20, 30, 40, 50]
numbers.append(60)
print(numbers)
numbers.remove(20)
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
numbers = [5, 10, 15, 20, 25]
sum = sum(numbers)
print("The sum of the numbers is:", sum)
# Out:
# The sum of the numbers is: 75

# %%
numbers = (1, 2, 3, 4, 5)
thirdElement = numbers[2]
print("The third element of the tuple is:", thirdElement)
# Out:
# The third element of the tuple is: 3

# %%
numbers = (10, 20, 30)
print("The original tuple is:", numbers)
numberList = list(numbers)
numberList.append(40)
# Out:
# The original tuple is: (10, 20, 30)

# %%
dic = {
    "name": "Ankit",
    "age": 21,
    "city": "Pokhara"
}

print("The age of the person is:", dic["age"])
# Out:
# The age of the person is: 21

# %%
dic = {"a": 1, "b": 2}
print("The value of key 'a' is:", dic["a"])
print("The value of key 'b' is:", dic["b"])

dic["c"] = 3
print("The updated dictionary is:", dic)
# Out:
# The value of key 'a' is: 1
# The value of key 'b' is: 2
# The updated dictionary is: {'a': 1, 'b': 2, 'c': 3}

# %%
# Create a set {1,2,3,4} and add the element 5.
mySet = {1, 2, 3, 4}
mySet.add(5)
print("The updated set is:", mySet)
# Out:
# The updated set is: {1, 2, 3, 4, 5}

# %%
mySet1 = {1,2,3}
mySet2 = {3,4,5}
unionSet = mySet1.union(mySet2)
print("The union of the sets is:", unionSet)
# Out:
# The union of the sets is: {1, 2, 3, 4, 5}
