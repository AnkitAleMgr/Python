# %%
import pandas as pd
import numpy as np


df = pd.read_csv("csv_files/expanded_employee_data.csv")

# %%
# Medium Challenge
# Employees with above-average Experience per Department – show Name, Department, Experience.
# Top 2 highest salaries per Country – display Name, Country, Salary.
# Employees with last names starting with a vowel – filter by Name column.
# Total Salary per Seniority level – calculate sum of Salary for Junior, Mid, Senior.

clone_df = df.copy()

# Employees with above-average Experience per Department – show Name, Department, Experience.
clone_df[clone_df["Experience"] > clone_df.groupby("Department")["Experience"].transform("mean")][["Name","Department","Experience"]]

# Top 2 highest salaries per Country – display Name, Country, Salary.
clone_df.groupby("Location").apply(lambda x : x.nlargest(2,"Salary"))[["EmployeeID","Name", "Location", "Salary"]].reset_index(drop= True)
# clone_df.sort_values(["Location", "Salary"], ascending=[True, False]).groupby("Location").head(2)[["Name","Location","Salary"]]

# Employees with last names starting with a vowel – filter by Name column.
clone_df

# clone_df["Name"] = ["Alice Smith", "Bob Evans", "Eve Johnson", "Oscar Lee", "Ian Brown"]

# # Filter employees whose last name starts with a vowel
# vowel_lastnames = clone_df[clone_df["Name"].apply(lambda x: x.split()[-1][0].upper() in ["A","E","I","O","U"])]
# print(vowel_lastnames)
# Out:
# /var/folders/pz/fb1v700s76dcwmgvjy5xqh0r0000gn/T/ipykernel_69361/2216095378.py:13: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   clone_df.groupby("Location").apply(lambda x : x.nlargest(2,"Salary"))[["EmployeeID","Name", "Location", "Salary"]].reset_index(drop= True)
#      EmployeeID          Name  Age Department   Position  Salary JoiningDate  \
# 0             1    Employee_1   50    Finance  Executive   72254  2010-01-31
# 1             2    Employee_2   36    Finance  Assistant   87362  2010-02-28
# 2             3    Employee_3   29    Finance    Manager   60128  2010-03-31
# 3             4    Employee_4   42         HR    Manager   99383  2010-04-30
# ...
