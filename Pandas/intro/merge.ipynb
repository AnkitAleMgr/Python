# %%
import pandas as pd

pd.set_option("display.max_columns", 50)
# pd.set_option("display.max_columns", 50)

climate_temp = pd.read_csv("csv_files/climate_temp.csv")
climate_precip = pd.read_csv("csv_files/climate_precip.csv")
climate_precip.head()
# Out:
#              STATION            STATION_NAME      DATE  DLY-PRCP-25PCTL  \
# 0  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100101            -6.66
# 1  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100102            -6.66
# 2  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100103            -6.66
# 3  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100104            -6.66
# 4  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100105            -6.66
#
#    DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  DLY-PRCP-50PCTL  DLY-SNWD-50PCTL  \
# 0             -666            -66.6            -6.66             -666
# 1             -666            -66.6            -6.66             -666
# 2             -666            -66.6            -6.66             -666
# 3            -9999          -9999.0            -6.66            -9999
# 4            -9999          -9999.0            -6.66            -9999
#
#    DLY-SNOW-50PCTL  DLY-PRCP-75PCTL  DLY-SNWD-75PCTL  DLY-SNOW-75PCTL  \
# ...

# %%
precip_one_station = climate_precip.query("STATION== 'GHCND:USC00045721'")
temp_one_station = climate_temp.query("STATION== 'GHCND:USC00045721'")

# %%
precip_one_station.head()
precip_one_station.shape
# Out:
# (365, 29)

# %%
temp_one_station.head()
# temp_one_station.shape
# Out:
#                 STATION            STATION_NAME ELEVATION LATITUDE  LONGITUDE  \
# 1460  GHCND:USC00045721  MITCHELL CAVERNS CA US    1325.9  34.9436  -115.5469
# 1461  GHCND:USC00045721  MITCHELL CAVERNS CA US    1325.9  34.9436  -115.5469
# 1462  GHCND:USC00045721  MITCHELL CAVERNS CA US    1325.9  34.9436  -115.5469
# 1463  GHCND:USC00045721  MITCHELL CAVERNS CA US    1325.9  34.9436  -115.5469
# 1464  GHCND:USC00045721  MITCHELL CAVERNS CA US    1325.9  34.9436  -115.5469
#
#           DATE  DLY-CLDD-BASE45  DLY-CLDD-BASE50  DLY-CLDD-BASE55  \
# 1460  20100101                3                1            -7777
# 1461  20100102                3                1            -7777
# 1462  20100103                3                1            -7777
# 1463  20100104                3                1            -7777
# 1464  20100105                3                1            -7777
#
#       DLY-CLDD-BASE57  DLY-CLDD-BASE60  DLY-CLDD-NORMAL  DLY-CLDD-BASE70  \
# ...

# %%
# merged_one_station = precip_one_station.merge(temp_one_station, left_index= True, right_index= True)
merged_one_station = precip_one_station.merge(temp_one_station)

merged_one_station.shape
# Out:
# (365, 47)

# %%
inner_merge_total = pd.merge(climate_temp,precip_one_station,  how= "left",on=["STATION", "DATE"])
inner_merge_total.shape
# climate_temp.shape
# Out:
# (127020, 48)
