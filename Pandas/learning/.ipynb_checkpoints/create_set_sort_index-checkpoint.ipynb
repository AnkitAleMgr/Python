# %%
import pandas as pd
import numpy as np
import random

# %%
df = pd.read_csv("csv_files/StudentsPerformance.csv")

# %%
clone_df = df.copy()

# %%
new_index = np.arange(0, 1000)

# %%
np.random.shuffle(new_index)

# %%
clone_df["new index"] = new_index

# %%
clone_df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  new index
# 0                    none          72             72             74        463
# 1               completed          69             90             88        584
# 2                    none          90             95             93        236
# 3                    none          47             57             44        894
# 4                    none          76             78             75        451

# %%
clone_df.set_index(new_index)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 463  female        group B           bachelor's degree      standard
# 584  female        group C                some college      standard
# 236  female        group B             master's degree      standard
# 894    male        group A          associate's degree  free/reduced
# 451    male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 388  female        group E             master's degree      standard
# 106    male        group C                 high school  free/reduced
# 877  female        group C                 high school  free/reduced
# 114  female        group D                some college      standard
# 428  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
clone_df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...
