# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("csv_files/StudentsPerformance.csv")

# %% [markdown]
# #### Assigne

# %% [markdown]
# #### it usuage:
# 1. to add multiple series as a cloumn in dataframe

# %%
df_copy = df.copy()

# %% [markdown]
# ##### making randon series to add as new column

# %%
value_1 = np.random.randint(0, 100, 1000)
value_2 = np.random.randint(0, 100, 1000)

# %%
df_copy.assign(**{'columne 1': value_1, 'columne 2' : value_2})
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %% [markdown]
# #### Insert

# %% [markdown]
# ##### it usuage:
# 1. to add comlumn in specific column index

# %%
df_copy.insert(1, "Test_column", value_1)

# %%
df_copy
# Out:
#      gender  Test_column race/ethnicity parental level of education  \
# 0    female           71        group B           bachelor's degree
# 1    female           88        group C                some college
# 2    female           24        group B             master's degree
# 3      male           53        group A          associate's degree
# 4      male           76        group C                some college
# ..      ...          ...            ...                         ...
# 995  female           19        group E             master's degree
# 996    male           47        group C                 high school
# 997  female           96        group C                 high school
# 998  female           86        group D                some college
# 999  female           70        group D                some college
#
#             lunch test preparation course  math score  reading score  \
# 0        standard                    none          72             72
# ...
